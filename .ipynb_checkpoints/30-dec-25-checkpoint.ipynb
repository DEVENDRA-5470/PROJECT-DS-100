# %%
a=12
print(a)
a="dev"
print(a)
a=23
print(a)
print(id(a))
# Out:
# 12
# dev
# 23
# 140731050194536

# %%
# 23="dev"
# print(23)
# # A variable cannot start with number.

# %%
# xy@z="dev"
# print(xy@z)
# A variable cannot start or include with any symbol, except(_).

# %%
# user name="dev"
# print(user name)
# A variable cannot include whitespace with any symbol.

# %%
# if="Dev"
# print(if)
# # A variable cannot be any python defined keyword.

# %%
# wap to add two numbers.
num1=20
num2=30
print(num1+num2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 4
#       2 num1=20
#       3 num2=30
# ----> 4 print(num1+num2)
#
# TypeError: 'str' object is not callable
