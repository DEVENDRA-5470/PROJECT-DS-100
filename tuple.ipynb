# %%
t=(20,30,40)
print(type(t))
print(t[0])
# t[0]=45
# print(t)
for i in t:
    print(i)
# Out:
# <class 'tuple'>
# 20
# 20
# 30
# 40

# %%
for i in range(len(t)):
    print(t[i])
# Out:
# 20
# 30
# 40

# %%
try:
    my_list=[(1,"aman",50,""),(2,"kamal",60,"Noida")]
    for i,j,k,l in my_list:
        print(i,j,k,l)
except Exception as e:
    print(e)
finally:
    print("Thanks for visiting")
# Out:
# 1 aman 50
# 2 kamal 60 Noida
# Thanks for visiting

# %%
try:
    my_list=[(1,"aman",50,""),(2,"kamal",60,"Noida")]
    for i,j,k in my_list:
        print(i,j,k,m)
except Exception as e:
    print("Customize msg :",e)
finally:
    print("Thanks")
# Out:
# Customize msg : too many values to unpack (expected 3)
# Thanks

# %%
try:
    num1=10
    num2=2
    res=num1/num2
    print(res)
    print(ress)
except ZeroDivisionError as z:
    print("Error:",z)
except NameError as z:
    print("Error:",z)
except TypeError as z:
    print("Error:",z)
# Out:
# 5.0
# Error: name 'ress' is not defined
